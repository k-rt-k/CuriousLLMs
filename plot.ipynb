# %%
import json
import plotly
import plotly.graph_objs as go

from typing import List, Tuple
from itertools import cycle

# %%
import os

dirname = "logs/rnd_training"

def get_data(filepath:str, metric:str)-> Tuple[List[int], List[float]]:
    steps = []
    values = []
    with open(filepath, 'r') as f:
        for line in f:
            data = json.loads(line)
            if metric in data:
                steps.append(data['step'])
                values.append(data[metric])
    return steps, values

def plot(traces: list[str], metric: str, labels: list[str] | None = None, 
         min_steps: int = 0, max_steps: int | None = None, 
         moving_avg: int | None = None, dirname: str = dirname):
    
    if labels is None:
        labels = traces
    assert len(traces) == len(labels)

    data = {}
    for trace, label in zip(traces, labels):
        print(f"Loading: {label}")
        filepath = os.path.join(dirname, trace, "metrics.jsonl")
        
        # Check if file exists to prevent crash
        if not os.path.exists(filepath):
            print(f"Warning: {filepath} not found.")
            continue
            
        steps, values = get_data(filepath, metric)
        
        # Filter max_steps immediately (cleaner to do it here)
        filtered = {}
        for s, v in zip(steps, values):
            if (max_steps is None or s <= max_steps):
                filtered[s] = v

        steps, values = zip(*sorted(filtered.items())) if filtered else ([], [])
        
        data[label] = (steps, values)

    # Use cycle to repeat colors if you have more lines than colors
    # We force 'red' for the first item, then cycle through the Plotly palette
    colors = ['red'] + plotly.colors.qualitative.Plotly[1+1:len(labels)+1]
    
    fig = go.Figure()
    
    # Iterate over items safely
    for i, (label, (steps, values)) in enumerate(data.items()):
        # Determine color
        color = colors[i]
        
        # --- FIX: Moving Average Logic ---
        if moving_avg is not None and moving_avg > 1:
            smoothed_values = []
            for k in range(len(values)):
                # Ensure we don't look back before index 0
                start_idx = max(0, k - moving_avg + 1)
                window = values[start_idx : k + 1]
                smoothed_values.append(sum(window) / len(window))
            values = smoothed_values

        # --- FIX: min_steps Filtering Logic ---
        # Filter pairs together so they don't get misaligned
        final_steps = []
        final_values = []
        for s, v in zip(steps, values):
            if s >= min_steps:
                final_steps.append(s)
                final_values.append(v)
        
        # Opacity logic (1.0 for first trace, 0.7 for others)
        op = 1.0 if i == 0 else 0.7

        fig.add_trace(go.Scatter(
            x=final_steps, 
            y=final_values, 
            mode='lines+markers', 
            name=label, 
            line=dict(color=color), 
            opacity=op
        ))

    fig.update_layout(title=f'{metric} over Update Steps', xaxis_title='Steps', yaxis_title=metric)
    fig.show()
    
    # File saving
    filename_base = f'{metric.replace("/", "_")}_plot_{"_".join(labels)}'
    fig.write_html(f'{filename_base}.html')
    fig.write_image(f'{filename_base}.pdf', width=1000, height=600)
    fig.update_layout(margin=dict(l=50, r=50, t=80, b=50))

# %% [markdown]
# ### First, total rewards and deepmath reward vs baseline

# %%
traces = ["OSS-vanilla", "oss-20B-both-pos-0.25-normalised", "oss-20B-both-pos-0.4", "oss-20B-deep-both-0.25", "oss-20B-deep-both-0.4"]
labels = ["Vanilla (No curiosity)", "λ=0.25,d=2", "λ=0.4,d=2", "λ=0.25,d=3", "λ=0.4,d=3"]

# %%
plot(traces, metric="env/deepmath/correct", labels=labels, max_steps=60, moving_avg=10, min_steps=20)
# Out:
# Loading: Vanilla (No curiosity)
# Loading: λ=0.25,d=2
# Loading: λ=0.4,d=2
# Loading: λ=0.25,d=3
# Loading: λ=0.4,d=3

# %%
plot(traces, metric="test/deepmath_test/env/all/correct", labels=labels, moving_avg = 5, max_steps=60, min_steps=20)
# Out:
# Loading: Vanilla (No curiosity)
# Loading: λ=0.25,d=2
# Loading: λ=0.4,d=2
# Loading: λ=0.25,d=3
# Loading: λ=0.4,d=3

# %% [markdown]
# ### Entropy for this setup

# %%
plot(traces, metric="optim/entropy", labels=labels , moving_avg = 5, max_steps=60, min_steps=20)
# Out:
# Loading: Vanilla (No curiosity)
# Loading: λ=0.25,d=2
# Loading: λ=0.4,d=2
# Loading: λ=0.25,d=3
# Loading: λ=0.4,d=3

# %% [markdown]
# ### Total tokens and rewards for Llama

# %%
llama_traces = ["Llama-3B-vanilla", "Llama-3B-both-pos-0.25-normalised"]
llama_labels = ["Vanilla (No curiosity)", "λ=0.25,d=2"]
plot(llama_traces, metric="env/deepmath/correct", labels=llama_labels)
# Out:
# Vanilla (No curiosity)
# α=0.25,d=2

# %%
plot(llama_traces, metric="env/math/correct", labels=llama_labels)
# Out:
# Vanilla (No curiosity)
# α=0.25,d=2

# %%
plot(llama_traces, metric="env/deepmath/ac_tokens_per_turn", labels=llama_labels)
# Out:
# Vanilla (No curiosity)
# α=0.25,d=2
